# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

random.seed(108)

# %%
#!git submodule add https://github.com/ultralytics/yolov5.git yolov5
#!cd yolov5
## remove .git file
# Out:
# 'Notebooks/yolov5_a' already exists in the index

# %%
# Change directory to YOLOv5 root 
#!pip install opencv-python

yolo_path = 'yolov5/'

import os
os.chdir(yolo_path)

# Train the model
# !python train.py --img 640 --batch 16 --epochs 10 --data custom_dataset/data.yaml --cfg models/yolov5s.yaml --weights ''
# Out:
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
# ...
#   Using cached ultralytics-8.2.35-py3-none-any.whl.metadata (41 kB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# ...
# Using cached ultralytics-8.2.35-py3-none-any.whl (782 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...

# %% [markdown]
# Inferenceing

# %%
# %cd yolov5 
# !python detect.py --weights /Users/rgoomer/Desktop/PCB_Detector_Yolo/pcb-component-detector/Notebooks/Yolo_addition/runs/train/exp/weights/best.pt --img 640 --conf 0.4 --source /Users/rgoomer/Desktop/PCB_Detector_Yolo/pcb-component-detector/Notebooks/Yolo_addition/custom_dataset/test/images
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /Users/rgoomer/Desktop/PCB_Detector_Yolo/pcb-component-detector/Notebooks/yolov5
# detect: weights=['/Users/rgoomer/Desktop/PCB_Detector_Yolo/pcb-component-detector/Notebooks/Yolo_addition/runs/train/exp/weights/best.pt'], source=/Users/rgoomer/Desktop/PCB_Detector_Yolo/pcb-component-detector/Notebooks/Yolo_addition/custom_dataset/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-324-gbb27bf78 Python-3.8.19 torch-2.3.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7034398 parameters, 0 gradients, 15.8 GFLOPs
# ...
